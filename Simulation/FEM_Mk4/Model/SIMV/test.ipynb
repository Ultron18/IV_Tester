# %%
import matplotlib.pyplot as plt
import ltspice

# %%
lt_single = ltspice.Ltspice('IVTesterFullCircuit - FIMV.raw')
lt.parse()

# %%
Vmeas = lt.get_data('V(vmeas)')
I = lt.get_data('I(R3)')

# %%
plt.plot(Vmeas,I)
plt.xlim([0,0.8])
# Out:
# (0.0, 0.8)
